# %% [markdown]
# # SoraNet DP Calibration
# This notebook loads the deterministic calibration artefacts generated by `scripts/telemetry/run_privacy_dp.py` and displays the scenario summary.

# %%
import json
import os
from pathlib import Path
artifact_root = Path(os.environ.get('SORANET_PRIVACY_DP_ARTIFACT_DIR', 'artifacts/soranet_privacy_dp'))
summary_path = artifact_root / 'summary.json'
summary = json.loads(summary_path.read_text())
summary
